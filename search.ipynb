# %%
import requests

url = "https://api.foursquare.com/v3/places/search"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3S4QbATMZblPviOe3grYFMQxepSf291wa6B/Boa24gTU="
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"results":[{"fsq_id":"4bfbb199565f76b04ccf05db","categories":[{"id":12064,"name":"Government Building","short_name":"Government","plural_name":"Government Buildings","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/building/government_","suffix":".png"}}],"chains":[],"closed_bucket":"LikelyOpen","distance":412,"geocodes":{"main":{"latitude":55.751999,"longitude":37.617734}},"link":"/v3/places/4bfbb199565f76b04ccf05db","location":{"country":"RU","formatted_address":"101000, Москва","locality":"Москва","postcode":"101000","region":"Москва"},"name":"The Kremlin (Кремль)","related_places":{"children":[{"fsq_id":"4ead38f561af352e5d058c31","categories":[{"id":16026,"name":"Monument","short_name":"Monument","plural_name":"Monuments","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/building/government_monument_","suffix":".png"}}],"name":"Тайницкая башня / The Taynitskaya Tower"},{"fsq_id":"53735cbc498e64c3501c3803","categories":[{"id":10030,"name":"History Museum","short_na
# ...

# %%
import requests

url = "https://api.foursquare.com/v3/places/search"

headers = {
    "Accept": "application/json",
    "Authorization": "fsq3S4QbATMZblPviOe3grYFMQxepSf291wa6B/Boa24gTU="
}

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {"results":[{"fsq_id":"4bfbb199565f76b04ccf05db","categories":[{"id":12064,"name":"Government Building","short_name":"Government","plural_name":"Government Buildings","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/building/government_","suffix":".png"}}],"chains":[],"closed_bucket":"LikelyOpen","distance":412,"geocodes":{"main":{"latitude":55.751999,"longitude":37.617734}},"link":"/v3/places/4bfbb199565f76b04ccf05db","location":{"country":"RU","formatted_address":"101000, Москва","locality":"Москва","postcode":"101000","region":"Москва"},"name":"The Kremlin (Кремль)","related_places":{"children":[{"fsq_id":"4ead38f561af352e5d058c31","categories":[{"id":16026,"name":"Monument","short_name":"Monument","plural_name":"Monuments","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/building/government_monument_","suffix":".png"}}],"name":"Тайницкая башня / The Taynitskaya Tower"},{"fsq_id":"53735cbc498e64c3501c3803","categories":[{"id":10030,"name":"History Museum","short_na
# ...

# %%
import requests
import json

# Ваши учетные данные API
client_id = "_______"
client_secret = "_______"

# Конечная точка API
endpoint = "https://api.foursquare.com/v3/places/search"

# Определение параметров для запроса API
city = input("Введите название города: ")
params = {
    "client_id": client_id,
    "client_secret": client_secret,
    "near": city,
    "query": "restaurant"
}

headers = {
    "Accept": "application/json",
    "Authorization": "fsq3S4QbATMZblPviOe3grYFMQxepSf291wa6B/Boa24gTU="
}

# Отправка запроса API и получение ответа
response = requests.get(endpoint, params=params,headers=headers)

# Проверка успешности запроса API
print(response.text)
if response.status_code == 200:
    print("Успешный запрос API!")
    data = json.loads(response.text)
    venues = data["results"]
    for venue in venues:
        # print("Название:", venue["name"])
        # print("Адрес:", venue["location"]["address"])
        print(venue)
        print("\n")
else:
    print("Запрос API завершился неудачей с кодом состояния:", response.status_code)
    print(response.text)
# Out:
# {"results":[{"fsq_id":"59dcac56da2e0054b468441e","categories":[{"id":13236,"name":"Italian Restaurant","short_name":"Italian","plural_name":"Italian Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/italian_","suffix":".png"}}],"chains":[],"closed_bucket":"Unsure","distance":638,"geocodes":{"main":{"latitude":55.756918,"longitude":37.621801},"roof":{"latitude":55.756918,"longitude":37.621801}},"link":"/v3/places/59dcac56da2e0054b468441e","location":{"address":"Никольская Ул., д. 11/13","address_extended":"стр. 1","country":"RU","cross_street":"","formatted_address":"Никольская Ул., д. 11/13, 109012, Москва","locality":"Москва","postcode":"109012","region":"Москва"},"name":"Il Pizzaiolo","related_places":{},"timezone":"Europe/Moscow"},{"fsq_id":"601d8dbf303b206d269515fe","categories":[{"id":13338,"name":"Seafood Restaurant","short_name":"Seafood","plural_name":"Seafood Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/seafood_","suffix
# ...

# %%
import requests
import json

# Ваши учетные данные API
client_id = "nephelim@ya.ru" # Замените на ваш ID
client_secret = "Ig04Nat30" # Замените на ваш секретный ключ

# Конечная точка API
endpoint = "https://api.foursquare.com/v3/places/search"

# Запрос категории
category = input("Введите интересующую вас категорию (например, кофейни, музеи, парки): ")

# Определение параметров для запроса API
city = input("Введите название города: ")
params = {
    "client_id": client_id,
    "client_secret": client_secret,
    "near": city,
    "query": category
    # "rating": "10"
}

headers = {
    "Accept": "application/json",
    "Authorization": "fsq3S4QbATMZblPviOe3grYFMQxepSf291wa6B/Boa24gTU="
}

# Отправка запроса API и получение ответа
response = requests.get(endpoint, params=params, headers=headers)

# Проверка успешности запроса API
if response.status_code == 200:
    print(f'Вы искали {category} в городе {city}')
    print('\n')

    data = json.loads(response.text)
    venues = data["results"]
    for venue in venues:
        name = venue["name"]
        address = venue["location"]["formatted_address"]
        latitude =  venue["location"]
        latitude = venue["geocodes"]["main"]["latitude"]
        longitude = venue["geocodes"]["main"]["longitude"]
        # rating = venue.get("rating", "Рейтинг недоступен") # Получение рейтинга, если он есть

        print(f"Название: {name}")
        print(f"Адрес: {address}")
        print(f"Широта: {latitude}")
        print(f"Долгота: {longitude}")
        # print(f"Рейтинг: {rating}")
        print("\n")

else:
    print("Запрос API завершился неудачей с кодом состояния:", response.status_code)
    print(response.text)
# Out:
# Вы искали Музеи в городе Санкт-петербург
#
#
# Название: Сказкин Дом
# Адрес: Александровский парк, 1а (Кронверкский пр.), 197198, Санкт-Петербург
# Широта: 59.953605
# Долгота: 30.309048
#
#
# Название: Russian Museum (Benois Wing) (Русский музей (Корпус Бенуа))
# Адрес: наб. Канала Грибоедова, 2 (Инженерная ул.), 191011, Санкт-Петербург
# Широта: 59.938661
# Долгота: 30.328853
#
#
# Название: Russian Museum (Русский музей)
# Адрес: Инженерная Ул., д. 4, 191186, Санкт-Петербург
# Широта: 59.938592
# Долгота: 30.332221
#
#
# Название: Fabergé Museum (Музей Фаберже)
# Адрес: наб. реки Фонтанки, 21, 191023, Санкт-Петербург
# Широта: 59.934779
# Долгота: 30.343095
#
#
# Название: Всероссийский Музей А.С.Пушкина (Музей-квартира А. С. Пушкина)
# Адрес: Наб. Реки Мойки, д. 12, 191186, Санкт-Петербург
# Широта: 59.940761
# Долгота: 30.32151
#
#
# Название: Научно-исследовательский музей Российской академии художеств
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = "https://foursquare.com/v/59c5678db3c9613aae5e59a4" # Замените venue-id на реальный ID места

response = requests.get(url)
print(response.text)
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')

    # Найдите элементы HTML, содержащие Rich Attributes
    # (например, div с определенным классом)
    rich_attributes_elements = soup.find_all('div', class_='rich-attribute')

    # Извлеките текст из элементов
    for element in rich_attributes_elements:
        print(element.text.strip())

else:
    print(f"Ошибка при получении данных: {response.status_code}")
# Out:
# <!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://www.facebook.com/2008/fbml" lang="en"><head><!-- OneTrust Cookies Consent Notice start for foursquare.com --><script src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js"  type="text/javascript" charset="UTF-8" data-domain-script="e15ad9c7-fa45-4538-987f-492b260b2805" ></script><script type="text/javascript">function OptanonWrapper() {}</script><!-- OneTrust Cookies Consent Notice end for foursquare.com --><script type="text/javascript">if (typeof window.performance === "object") {window.timingData = {}; window.timingData.results = {}; window.timingData.results.codeStart = Math.round(window.performance.now());}</script><title>Tilda Food &amp; Bar - Патриаршие пруды - 75 tips from 959 visitors</title><meta content="en" http-equiv="Content-Language" /><meta content="text/html; charset=UTF-8" http-equiv="Content-Type" /><meta content="Foursquare" name="applic
# ...

# %%
import requests
import json

# Ваши учетные данные API
client_id = "YOUR_CLIENT_ID" # Замените на ваш ID
client_secret = "YOUR_CLIENT_SECRET" # Замените на ваш секретный ключ

# Конечная точка API
endpoint = "https://api.foursquare.com/v3/places/search"

# Запрос категории
category = input("Введите интересующую вас категорию (например, кофейни, музеи, парки): ")

# Определение параметров для запроса API
city = input("Введите название города: ")
params = {
    "client_id": client_id,
    "client_secret": client_secret,
    "near": city,
    "query": category
}

headers = {
    "Accept": "application/json",
    "Authorization": "fsq3S4QbATMZblPviOe3grYFMQxepSf291wa6B/Boa24gTU="
}

# Отправка запроса API и получение ответа
response = requests.get(endpoint, params=params, headers=headers)

# Проверка успешности запроса API
if response.status_code == 200:
    print("Успешный запрос API!")
    data = json.loads(response.text)
    venues = data["results"]
    for venue in venues:
        name = venue["name"]
        address = venue["location"]["formatted_address"]
        rating = venue.get("rating", "Рейтинг недоступен")
        
        # Дополнительные поля
        phone = venue["location"].get("phone", "Телефон недоступен") 
        categories = venue["categories"]
        cuisine = None
        for cat in categories:
            if cat["name"] in ["Cafe", "Restaurant", "Food", "Coffee Shop"]:
                cuisine = cat.get("shortName", "Тип кухни недоступен")
                break
        
        # Часы работы
        hours = venue.get("hours") # Используем get для безопасного доступа
        if hours:
            if hours["status"] == "OPEN":
                print(f"Сейчас открыто!")
            elif hours["status"] == "CLOSED":
                print(f"Сейчас закрыто!")
            timeframes = hours.get("timeframes", []) 
            if timeframes:
                for timeframe in timeframes:
                    open_time = timeframe.get("open", {}).get("time", "Время открытия недоступно")
                    close_time = timeframe.get("close", {}).get("time", "Время закрытия недоступно")
                    print(f"Время работы: {open_time} - {close_time}")
        else:
            print("Часы работы недоступны.")

        print(f"Название: {name}")
        print(f"Адрес: {address}")
        print(f"Рейтинг: {rating}")
        print(f"Телефон: {phone}")
        print(f"Тип кухни: {cuisine}")
        print("\n")

else:
    print("Запрос API завершился неудачей с кодом состояния:", response.status_code)
    print(response.text)
# Out:
# Успешный запрос API!
# Часы работы недоступны.
# Название: Turandot (Турандот)
# Адрес: Тверской б Ул., д. 26, 125009, Москва
# Рейтинг: Рейтинг недоступен
# Телефон: Телефон недоступен
# Тип кухни: None
#
#
# Часы работы недоступны.
# Название: Cafe Pushkin (Кафе Пушкинъ)
# Адрес: Тверской бульв., 26а (Тверская ул.), 125009, Москва
# Рейтинг: Рейтинг недоступен
# Телефон: Телефон недоступен
# Тип кухни: None
#
#
# Часы работы недоступны.
# Название: White Rabbit
# Адрес: Смоленская пл., 3, 119002, Москва
# Рейтинг: Рейтинг недоступен
# Телефон: Телефон недоступен
# Тип кухни: None
#
#
# Часы работы недоступны.
# Название: Beluga (Белуга)
# Адрес: Моховая Ул., д. 15/1, 125009, Москва
# Рейтинг: Рейтинг недоступен
# Телефон: Телефон недоступен
# Тип кухни: None
#
#
# Часы работы недоступны.
# Название: Novikov Restaurant & Bar
# Адрес: Тверская Ул., д. 3, 125009, Москва
# Рейтинг: Рейтинг недоступен
# Телефон: Телефон недоступен
# Тип кухни: None
#
#
# Часы работы недоступны.
# ...
